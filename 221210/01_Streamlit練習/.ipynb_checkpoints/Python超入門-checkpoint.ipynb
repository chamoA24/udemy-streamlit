# %%
1 < 3
# Out:
# True

# %%
1 == 1
# Out:
# True

# %%
a=100

# %%
a
# Out:
# 100

# %%
type(a)
# Out:
# int

# %%
b=1.01
b
# Out:
# 1.01

# %%
type(b)
# Out:
# float

# %%
c = 3j

# %%
c
# Out:
# 3j

# %%
type(c)
# Out:
# complex

# %%
name = 'ozaki'

# %%
type(name)
# Out:
# str

# %%
flg = True

# %%
type(flg)
# Out:
# bool

# %%
d = [10, 20, 30]
d
# Out:
# [10, 20, 30]

# %%
type(d)
# Out:
# list

# %%
e = {}

# %%
type(e)
# Out:
# dict

# %%
names = ['尾﨑', '加藤', '鈴木']
names
# Out:
# ['尾﨑', '加藤', '鈴木']

# %%
names[0]
# Out:
# '尾﨑'

# %%
names[-1]
# Out:
# '鈴木'

# %%
names[0:2]
# Out:
# ['尾﨑', '加藤']

# %%
scores = [40, 20, 30]

# %%
scores.append(50)

# %%
scores
# Out:
# [40, 20, 30, 50]

# %%
scores.pop()
# Out:
# 50

# %%
scores
# Out:
# [40, 20, 30]

# %%
scores.pop(0)
# Out:
# 40

# %%
scores = {'国語':40, 
          '数学':90 }
scores
# Out:
# {'国語': 40, '数学': 90}

# %%
scores['国語']
# Out:
# 40

# %%
scores['家庭科'] = 100

# %%
scores
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 socres
#
# NameError: name 'socres' is not defined

# %%
scores
# Out:
# {'国語': 40, '数学': 90, '家庭科': 100}

# %%
scores.pop('家庭科')
# Out:
# 100

# %%
scores
# Out:
# {'国語': 40, '数学': 90}

# %%
money = 2000

# %%
if money >= 8000:
    print('ディズニーランドに行きます')
elif money >= 2000 and money < 8000:
    print('映画館に行きます')
else:
    print('映画館には行きません')
# Out:
# 映画館に行きます
